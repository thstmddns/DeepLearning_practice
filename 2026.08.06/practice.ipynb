# %%
import numpy as np

# %%
# 계단함수 구현(부동소수점)
def step_function(x):
    if x > 0:
        return 1
    else:
        return 0

# %%
# 계단함수 구현(numpy 입력)
def step_function(x):
    if x > 0:
        return x.astype(int)
